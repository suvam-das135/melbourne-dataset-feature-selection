# %%
# !pip install category_encoders
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: category_encoders in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (1.19.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (1.2.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\appdata\roaming\python\python38\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: six in c:\users\asus\appdata\roaming\python\python38\site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\asus\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)

# %% [markdown]
# **LOAD DATASET**

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-292f82be1b7a> in <module>
# ----> 1 from google.colab import files
#       2
#       3 uploaded = files.upload()
#       4
#       5 for fn in uploaded.keys():
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
df = pd.read_csv("melb_data.csv")
df.head(5)
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN        Yarra  -37.7996    144.9984  Northern Metropolitan
# 1     1900.0        Yarra  -37.8079    144.9934  Northern Metropolitan
# 2     1900.0        Yarra  -37.8093    144.9944  Northern Metropolitan
# 3        NaN        Yarra  -37.7969    144.9969  Northern Metropolitan
# 4     2014.0        Yarra  -37.8072    144.9941  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
x = df.drop('Price', axis=1)
y = df['Price']

# %%
x.shape
# Out:
# (13580, 20)

# %% [markdown]
# **DATA PREPROSESSING: FILLING MISSING DATA**

# %%
x = x.fillna(method='bfill')
x.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea      1367
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# **DATA PREPROSESSING: ENCODING DATA**

# %%
import category_encoders as ce
encoder = ce.OrdinalEncoder()
x = encoder.fit_transform(x)

# %%
feature_name = x.columns

# %%
# SPLITTING DATASET IN TRAINING AND TEST

# %% [markdown]
# **SPLITTING DATASET IN TRAINING AND TEST**

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into 30% test and 70% training
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %% [markdown]
# **ANOVA F-value**

# %%
from sklearn.feature_selection import f_regression
f_value = f_regression(x, y)

for feature in zip(feature_name, f_value[0]):
    print(feature)
# Out:
# ('Suburb', 535.665725536852)
# ('Address', 44.85270433499009)
# ('Rooms', 4445.375633002306)
# ('Type', 1503.2665444898605)
# ('Method', 6.01957293596673)
# ('SellerG', 235.05487476189103)
# ('Date', 3.4531844060184036)
# ('Distance', 368.3703298271484)
# ('Postcode', 159.8437653098493)
# ('Bedroom2', 3976.642336177954)
# ('Bathroom', 3787.939784140625)
# ('Car', 815.9939118764494)
# ('Landsize', 19.12856029322579)
# ('BuildingArea', 80.95932153465114)
# ('YearBuilt', 778.5650742157733)
# ('CouncilArea', 64.62769615244925)
# ('Lattitude', 644.8754062908355)
# ('Longtitude', 587.5248006350955)
# ('Regionname', 359.3181625520915)
# ('Propertycount', 24.168917653219914)

# %%
plt.bar(x=feature_name, height=f_value[0], color='blue')
plt.xticks(rotation='vertical')
plt.ylabel('F-value')
plt.title('F-value Comparison')
plt.show()

# %% [markdown]
# **Variance Threshold**

# %%
from sklearn.feature_selection import VarianceThreshold
select = VarianceThreshold()
select.fit_transform(x)


for feature in zip(feature_name, select.variances_):
    print(feature)
# Out:
# ('Suburb', 313.0)
# ('Address', 13377.0)
# ('Rooms', 0.9133868571341811)
# ('Type', 0.4011211313093629)
# ('Method', 1.0695640084070612)
# ('SellerG', 267.0)
# ('Date', 57.0)
# ('Distance', 34.4393962326561)
# ('Postcode', 977.0)
# ('Bedroom2', 0.9329347932179568)
# ('Bathroom', 0.4784298739157689)
# ('Car', 0.9269341067280349)
# ('Landsize', 433014.0)
# ('BuildingArea', 44515.0)
# ('YearBuilt', 822.0)
# ('CouncilArea', 33.0)
# ('Lattitude', 0.0062816568783015505)
# ('Longtitude', 0.010797648730010415)
# ('Regionname', 1.4099021778974101)
# ('Propertycount', 21401.0)

# %%
plt.bar(x=feature_name, height=select.variances_, color='green')
plt.xticks(rotation='vertical')
plt.ylabel('Variance')
plt.title('Variance Comparison')

plt.show()

# %% [markdown]
# **Mutual Information**

# %%
from sklearn.feature_selection import mutual_info_regression
mc = mutual_info_regression(x, y, random_state=0)

# Print the name and mutual information score of each feature
for feature in zip(feature_name, mc):
    print(feature)
# Out:
# ('Suburb', 0.2649205603703786)
# ('Address', 0.1091906946854575)
# ('Rooms', 0.2194660087435909)
# ('Type', 0.1760787903413248)
# ('Method', 0.11678454809058492)
# ('SellerG', 0.14072864117870232)
# ('Date', 0.01676424360447104)
# ('Distance', 0.20788798483696969)
# ('Postcode', 0.3206683586403756)
# ('Bedroom2', 0.2070763270797107)
# ('Bathroom', 0.11799278455621076)
# ('Car', 0.09547635833036239)
# ('Landsize', 0.1456076333435261)
# ('BuildingArea', 0.13378763395665771)
# ('YearBuilt', 0.0655217509947823)
# ('CouncilArea', 0.19170399566849872)
# ('Lattitude', 0.1482978319605337)
# ('Longtitude', 0.15425776116539414)
# ('Regionname', 0.10482462812179705)
# ('Propertycount', 0.2027044337558257)

# %%
plt.figure(figsize=(4,4))
plt.bar(x=feature_name, height=mc, color='tomato')
plt.xticks(rotation='vertical')
plt.ylabel('Mutual Information Score')
plt.title('Mutual Information Score Comparison')

plt.show()

# %% [markdown]
# **Using Selector Object for Selecting Features**

# %%
from sklearn.feature_selection import SelectKBest
skb = SelectKBest(score_func=f_regression, k=6)                  
x_new = skb.fit_transform(x, y)

print('Number of features before feature selection: {}'.format(x.shape[1]))
print('Number of features after feature selection: {}'.format(x_new.shape[1]))
# Out:
# Number of features before feature selection: 20
# Number of features after feature selection: 6

# %%
# FEATURE SELECTION FROM SEQUENTIAL FORWARD SELECTION

# %% [markdown]
# **FEATURE SELECTION FROM SEQUENTIAL FORWARD SELECTION**

# %%
from sklearn.linear_model import LinearRegression
from mlxtend.feature_selection import SequentialFeatureSelector
sel = SequentialFeatureSelector(estimator=LinearRegression(),k_features=(1,20), forward=True)
sel.fit(x_train, y_train)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(1, 20))

# %%
print('Best accuracy score: %.2f' % sel.k_score_)   # k_score_ shows the best score 
print('Best subset (indices):', sel.k_feature_idx_) # k_feature_idx_ shows the index of features 
                                                    # that yield the best score
print('Best subset (corresponding names):', sel.k_feature_names_)
# Out:
# Best accuracy score: 0.56
# Best subset (indices): (0, 1, 2, 3, 4, 5, 7, 8, 10, 11, 14, 16, 17, 18)
# Best subset (corresponding names): ('Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Distance', 'Postcode', 'Bathroom', 'Car', 'YearBuilt', 'Lattitude', 'Longtitude', 'Regionname')

# %%
# FEATURE SELECTION FROM SEQUENTIAL BACKWARD SELECTION

# %% [markdown]
# **FEATURE SELECTION FROM SEQUENTIAL BACKWARD SELECTION**

# %%
selb = SequentialFeatureSelector(estimator=LinearRegression(),k_features=(1,20), forward=False)
selb.fit(x_train, y_train)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), forward=False,
#                           k_features=(1, 20))

# %%
print('Best accuracy score: %.2f' % sel.k_score_)   # k_score_ shows the best score 
print('Best subset (indices):', sel.k_feature_idx_) # k_feature_idx_ shows the index of features 
                                                    # that yield the best score
print('Best subset (corresponding names):', sel.k_feature_names_)
# Out:
# Best accuracy score: 0.56
# Best subset (indices): (0, 1, 2, 3, 4, 5, 7, 8, 10, 11, 14, 16, 17, 18)
# Best subset (corresponding names): ('Suburb', 'Address', 'Rooms', 'Type', 'Method', 'SellerG', 'Distance', 'Postcode', 'Bathroom', 'Car', 'YearBuilt', 'Lattitude', 'Longtitude', 'Regionname')

# %%
# FEATURE SELECTION FROM RANDOM FOREST USING SelectFromModel

# %% [markdown]
# **FEATURE SELECTION FROM RANDOM FOREST USING SelectFromModel**

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
selector = SelectFromModel(estimator=RandomForestRegressor())
selector.fit(x_train, y_train)
# Out:
# SelectFromModel(estimator=RandomForestRegressor())

# %% [markdown]
# SELECTED FEATURES NAME

# %%
print('The most important features based on random forest classifier:')
for feature_list_index in selector.get_support(indices=True):
    print('- ' + feature_name[feature_list_index])
# Out:
# The most important features based on random forest classifier:
# - Rooms
# - Type
# - Distance
# - Postcode
# - Bathroom
# - Landsize

# %% [markdown]
# FEATURES REDUCED FROM 20 TO 6

# %%
x_imp_train = selector.transform(x_train)
x_imp_test = selector.transform(x_test)

# Print the results
print('Number of features before transformation: {}'.format(x_train.shape[1]))
print('Number of features after transformation: {}'.format(x_imp_train.shape[1]))
# Out:
# Number of features before transformation: 20
# Number of features after transformation: 6

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# ACCURACY FROM FULL FEATURES

# %%
rfr_full = RandomForestRegressor()

rfr_full.fit(x_train, y_train)

# Make predictions
pred_full = rfr_full.predict(x_test)

# Generate accuracy score
print("r2 score: ",r2_score(y_test, pred_full))
# Out:
# r2 score:  0.7715684648105945

# %% [markdown]
# ACCURACY FROM IMPORTANT FEATURES

# %%
rfr_lim = RandomForestRegressor()

# Train the classifier with limited features
rfr_lim.fit(x_imp_train, y_train)

# Make predictions
pred_lim = rfr_lim.predict(x_imp_test)

print("r2 score: ",r2_score(y_test, pred_lim))
# Out:
# r2 score:  0.7268098300716825

# %%
# FEATURE SELECTION USING EXHAUSTIVE FEATURE SELECTION

# %% [markdown]
# **FEATURE SELECTION USING EXHAUSTIVE FEATURE SELECTION**

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector
efs = ExhaustiveFeatureSelector(estimator=LinearRegression(), min_features=1, max_features=3, print_progress=True, cv=2)
efs = efs.fit(x_train, y_train)
print(efs.best_feature_names_)
# Out:
# Features: 1350/1350
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-38-5bf32f060104> in <module>
#       1 from mlxtend.feature_selection import ExhaustiveFeatureSelector
#       2 efs = ExhaustiveFeatureSelector(estimator=LinearRegression(), min_features=1, max_features=3, print_progress=True, cv=2)
# ----> 3 efs = efs.fit(x_train, y_train)
#       4 print(efs.best_feature_names_)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py in fit(self, X, y, custom_feature_names, groups, **fit_params)
#     307                 best_subset = c
#     308         score = max_score
# --> 309         idx = self.subsets_[best_subset]['feature_idx']
#     310
#     311         self.best_idx_ = idx
#
# UnboundLocalError: local variable 'best_subset' referenced before assignment
